# %% [markdown]
# # 02. Modelo

# %% [markdown]
# ### Librerias

# %%
import pandas as pd

# %% [markdown]
# ### Carga del dataset limpio

# %%
dt_quejas = pd.read_csv('..\data\dt_quejas_corr.csv')
dt_quejas.head(20)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Jon\AppData\Local\Temp\ipykernel_3444\1742754170.py:1: SyntaxWarning: invalid escape sequence '\d'
#   dt_quejas = pd.read_csv('..\data\dt_quejas_corr.csv')
#     Complaint ID                  Product                       Sub-product  \
# 0        1291006          Debt collection                       Credit card
# 1        1290580          Debt collection                           Medical
# 2        1290564                 Mortgage                      FHA mortgage
# 3        1291615              Credit card                           Unknown
# 4        1292165          Debt collection          Non-federal student loan
# 5        1291176          Debt collection                       Payday loan
# 6        1288848            Consumer loan                  Installment loan
# 7        1288788          Debt collection                       Payday loan
# ...
